# %% [markdown]
# 1) cars data set

# %%
import csv
with open("C:/Users/User/Pictures/audi.csv","r") as file :
    set=csv.reader(file)
    i=0
    for data in set:
        
        print(data)
# Out:
# ['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg', 'engineSize']
# [' A1', '2017', '12500', 'Manual', '15735', 'Petrol', '150', '55.4', '1.4']
# [' A6', '2016', '16500', 'Automatic', '36203', 'Diesel', '20', '64.2', '2']
# [' A1', '2016', '11000', 'Manual', '29946', 'Petrol', '30', '55.4', '1.4']
# [' A4', '2017', '16800', 'Automatic', '25952', 'Diesel', '145', '67.3', '2']
# [' A3', '2019', '17300', 'Manual', '1998', 'Petrol', '145', '49.6', '1']
# [' A1', '2016', '13900', 'Automatic', '32260', 'Petrol', '30', '58.9', '1.4']
# [' A6', '2016', '13250', 'Automatic', '76788', 'Diesel', '30', '61.4', '2']
# [' A4', '2016', '11750', 'Manual', '75185', 'Diesel', '20', '70.6', '2']
# [' A3', '2015', '10200', 'Manual', '46112', 'Petrol', '20', '60.1', '1.4']
# [' A1', '2016', '12000', 'Manual', '22451', 'Petrol', '30', '55.4', '1.4']
# [' A3', '2017', '16100', 'Manual', '28955', 'Petrol', '145', '58.9', '1.4']
# ...

# %%
import csv
with open("C:/Users/User/Pictures/audi.csv","r") as file :
    set=csv.reader(file)
    i=0
    for data in set:
        
        if data[1]=="2020":
            i=i+1
            print(data[0],data[3])
    print("countingh the number of cars in 2020:",i)#counting the number of cars in 2020
# Out:
#  Q7 Semi-Auto
#  Q5 Semi-Auto
#  Q5 Semi-Auto
#  A4 Semi-Auto
#  Q7 Semi-Auto
#  A3 Semi-Auto
#  A4 Semi-Auto
#  A4 Semi-Auto
#  A4 Manual
#  A5 Semi-Auto
#  A5 Semi-Auto
#  A5 Semi-Auto
#  Q3 Semi-Auto
#  A4 Semi-Auto
#  A5 Semi-Auto
#  A4 Semi-Auto
#  A8 Semi-Auto
#  RS4 Semi-Auto
#  A7 Semi-Auto
#  A4 Semi-Auto
#  Q2 Semi-Auto
#  A1 Manual
#  Q3 Semi-Auto
#  Q3 Semi-Auto
#  A3 Semi-Auto
#  A1 Manual
#  Q5 Semi-Auto
#  Q2 Manual
#  Q3 Semi-Auto
#  Q2 Semi-Auto
#  Q3 Semi-Auto
#  Q3 Semi-Auto
#  Q3 Semi-Auto
#  Q5 Semi-Auto
#  Q3 Semi-Auto
#  Q3 Semi-Auto
#  Q2 Semi-Auto
#  Q2 Semi-Auto
#  Q3 Semi-Auto
#  A1 Semi-Auto
#  Q2 Manual
#  A1 Semi-Auto
#  TT Semi-Auto
#  A3 Semi-Auto
#  Q8 Automatic
#  Q2 Manual
#  Q5 Semi-Auto
#  Q3 Semi-Auto
#  A1 Semi-Auto
#  A3 Semi-Auto
#  Q3 Semi-Auto
#  Q2 Manual
#  Q5 Semi-Auto
#  Q3 Semi-Auto
#  A5 Semi-Auto
#  Q3 Semi-Auto
#  Q3 Semi-Auto
#  Q3 Semi-Auto
#  A4 Semi-Auto
#  TT Semi-Auto
#  Q3 Semi-Auto
#  Q3 Semi-Auto
#  A3 Semi-Auto
# ...

# %%
import csv
with open("C:/Users/User/Pictures/audi.csv","r") as file :
    set=csv.reader(file)
    i=0
    for data in set:
        
        if data[1]=="2020" and data[3]=="Manual":
            i=i+1
            print(data[0],data[3])
    print("countingh the number of manual cars in 2020",i)
# Out:
#  A4 Manual
#  A1 Manual
#  A1 Manual
#  Q2 Manual
#  Q2 Manual
#  Q2 Manual
#  Q2 Manual
#  A1 Manual
#  A1 Manual
#  A1 Manual
#  A1 Manual
#  Q2 Manual
#  A3 Manual
#  A4 Manual
#  A3 Manual
#  Q3 Manual
#  A4 Manual
#  A4 Manual
#  A4 Manual
#  Q2 Manual
#  Q2 Manual
#  A1 Manual
#  Q3 Manual
#  A1 Manual
#  Q3 Manual
#  Q3 Manual
#  Q3 Manual
#  A3 Manual
#  A3 Manual
#  Q2 Manual
#  A3 Manual
#  A3 Manual
#  Q3 Manual
#  A1 Manual
#  A1 Manual
#  A1 Manual
#  A3 Manual
#  A1 Manual
#  A3 Manual
#  Q2 Manual
#  A1 Manual
#  A1 Manual
#  A1 Manual
#  A1 Manual
#  A1 Manual
#  Q2 Manual
#  A1 Manual
#  Q2 Manual
#  Q3 Manual
#  Q3 Manual
#  Q2 Manual
#  A5 Manual
#  Q2 Manual
#  Q2 Manual
#  Q2 Manual
#  Q2 Manual
#  Q3 Manual
#  A3 Manual
#  A1 Manual
#  A1 Manual
#  A4 Manual
#  Q2 Manual
#  A4 Manual
#  A4 Manual
#  A3 Manual
#  A4 Manual
#  A4 Manual
#  Q3 Manual
#  A1 Manual
#  Q3 Manual
#  Q3 Manual
#  Q3 Manual
#  Q2 Manual
#  Q3 Manual
#  A3 Manual
#  Q3 Manual
# ...

# %%
import csv
with open("C:/Users/User/Pictures/audi.csv","r") as file :
    set=csv.reader(file)
    i=0
    for data in set:
        
        if data[1]=="2020" and data[8]=="1.4":#
            i=i+1
            print(i,data[0],data[8])#printing number of cars having engine size 1.4 in 2020
# Out:
# 1  A3 1.4
# 2  A3 1.4

# %%
import csv
with open("C:/Users/User/Pictures/audi.csv","r") as file :
    set=csv.reader(file)
    i=0
    for data in set:
        
        if data[1]=="2020" and data[8]=="1.4":#
            i=i+1
            if data[5]=="Petrol":
                print(data[0],data[5])
                # number of cars having petrol engine size 1.4 in 2020 

            else:
                print("there is no petrol engine cars having size 1.4  in 2020]")
# Out:
# there is no petrol engine cars having size 1.4  in 2020]
# there is no petrol engine cars having size 1.4  in 2020]

# %%
import csv
with open("C:/Users/User/Pictures/audi.csv","r") as file :
    set=csv.reader(file)
    i=0
    for data in set:
        
        if data[1]=="2020" and data[8]=="1.4":
            
            if data[5]=="Diesel":
                print(data[0],data[5])

            else:
                print("there is no diesel engine cars in  :2020")
# Out:
# there is no diesel engine cars in  :2020
# there is no diesel engine cars in  :2020

# %% [markdown]
# 2) amazon data set

# %%
import csv
with open ("C:/Users/User/Desktop/book1.csv","r")as file:
    csvfile=csv.reader(file)
    i=0
    for line in  csvfile:
        # printing all the exell data in list format
        print(line)
        # skiping row 1
        i=i+1
        if i==2:#to remove specific row
            continue
        # line.remove(line[1])
# Out:
# ['number', 'ID', 'Delivery_person_ID', 'Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude', 'Time_Orderd', 'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density', 'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle', 'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)']
# ['1', '0x4607_x', 'INDORES13DEL02', '37', '4.9', '22.745049', '75.892471', '22.765049', '75.912471', '11:30', '11:45', '4', '0', '2', '3', '3', '0', '1', '3', '24']
# ['2', '0xb379_x', 'BANGRES18DEL02', '34', '4.5', '12.913041', '77.683237', '13.043041', '77.813237', '19:45', '19:50', '3', '1', '2', '3', '4', '1', '1', '1', '33']
# ['3', '0x20f7_x', 'BANGRES18DEL01', '37', '4.4', '12.913041', '77.683237', '12.953041', '77.723237', '13:50', '13:55', '6', '0', '0', '0', '3', '2', '1', '1', '42']
# ...

# %%
import csv
with open ("C:/Users/User/Desktop/book1.csv","r")as file:
    csvfile=csv.reader(file)
    i=0
    for line in  csvfile:
            print(line)# printing only first row 
            break
        # if line[0]:
        #     print(line[0])
            # break
# Out:
# ['number', 'ID', 'Delivery_person_ID', 'Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude', 'Time_Orderd', 'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density', 'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle', 'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)']

# %%
import csv
with open ("C:/Users/User/Desktop/book1.csv","r")as file:
    csvfile=csv.reader(file)
    i=0
    for line in  csvfile:
        if line[4]=="4.9":
            print(line[0],line[4])#printing only 4.9 star rating in excel
# Out:
# 1 4.9
# 4 4.9
# 16 4.9
# 18 4.9
# 21 4.9
# 24 4.9
# 28 4.9
# 41 4.9
# 51 4.9
# 66 4.9
# 67 4.9
# 73 4.9
# 74 4.9
# 76 4.9
# 77 4.9
# 84 4.9
# 85 4.9
# 87 4.9
# 97 4.9
# 105 4.9
# 123 4.9
# 127 4.9
# 129 4.9
# 133 4.9
# 138 4.9
# 144 4.9
# 148 4.9
# 155 4.9
# 160 4.9
# 183 4.9
# 184 4.9
# 191 4.9
# 200 4.9
# 203 4.9
# 212 4.9
# 214 4.9
# 215 4.9
# 225 4.9
# 233 4.9
# 246 4.9
# 254 4.9
# 255 4.9
# 256 4.9
# 258 4.9
# 265 4.9
# 272 4.9
# 279 4.9
# 281 4.9
# 283 4.9
# 291 4.9
# 296 4.9
# 297 4.9
# 299 4.9
# 300 4.9
# 310 4.9
# 314 4.9
# 317 4.9
# 324 4.9
# 344 4.9
# 346 4.9
# 350 4.9
# 354 4.9
# 355 4.9
# 361 4.9
# 366 4.9
# 372 4.9
# 382 4.9
# 390 4.9
# 392 4.9
# 404 4.9
# 407 4.9
# 414 4.9
# 425 4.9
# 430 4.9
# 443 4.9
# 444 4.9
# 446 4.9
# 454 4.9
# 470 4.9
# 474 4.9
# 475 4.9
# 478 4.9
# 483 4.9
# 485 4.9
# 486 4.9
# 489 4.9
# 490 4.9
# 499 4.9
# 502 4.9
# 506 4.9
# 508 4.9
# 510 4.9
# 518 4.9
# 523 4.9
# 533 4.9
# 535 4.9
# 537 4.9
# 542 4.9
# 543 4.9
# 548 4.9
# 558 4.9
# 565 4.9
# ...

# %%
import csv
with open ("C:/Users/User/Desktop/book1.csv","r")as file:
    csvfile=csv.reader(file)
    i=0
    for line in  csvfile:
        
        if line[4]== float(4.9):
            print(line[4].remove(4.9))#removing line[4] having 4.9 star rating
        print(line[4])
# Out:
# Delivery_person_Ratings
# 4.9
# 4.5
# 4.4
# 4.9
# 4.6
# 4.7
# 4.8
# 5
# 4.6
# 4.8
# 4.4
# 4.2
# 4.8
# 4.7
# 5
# 4.9
# 4.7
# 4.9
# 4.3
# 4.6
# 4.9
# 4.6
# 4.5
# 4.9
#
# 4.6
# 5
# 4.9
# 4.7
# 4.8
# 4.7
# 4.6
# 4.6
# 4.8
# 4.6
# 4.7
# 4.8
# 4.7
# 4.8
# 4.7
# 4.9
# 4.7
# 4.7
# 4.8
# 5
# 4.7
# 4.8
# 4.8
# 4.7
# 4.5
# 4.9
# 5
# 3.9
# 4.8
# 4.6
# 4.8
# 5
# 4.8
# 3.9
# 4.8
# 4.7
# 4.6
# 5
# 4.7
# 4.7
# 4.9
# 4.9
# 4.8
# 5
# 4.4
# 4.7
# 4.8
# 4.9
# 4.9
#
# 4.9
# 4.9
# 4.7
# 4.8
# 4.8
# 4.7
# 4.7
# 4.7
# 4.9
# 4.9
#
# 4.9
# 5
# 4.5
# 4.8
# 4.1
# 4.8
# 4
# 4.8
# 4.8
# 4
# 4.9
# 4.2
# 3.4
# 5
# 4.7
# 4.8
# 4.8
# 4.7
# 4.9
# 4.1
# 4.8
# 4.6
# 4.7
# 4.8
# 4.8
# 5
# 5
# 4.4
# 4.6
#
# 4.6
# 5
# 4.4
# 4.8
# 4.3
# 4.6
# 4.9
# 4.3
# 5
# 4.8
# 4.9
# 3.5
# 4.9
# 4.1
# 4.6
# 4.6
# 4.9
# 4.4
# 4.5
# 4.7
# 4.8
# 4.9
# 4.3
# 4.7
# 4.5
# 4.7
# 4.2
# 4.9
# 4.7
# 4.7
# 4.8
# 4.9
# 5
# 4.8
# 4.6
# 4
# 4.8
# 4.6
# 4.9
# 5
# 4.8
# 4.7
# 4.4
# 4.9
# 4.8
# 4.8
# 4.7
# 4.8
# 4.6
# 4.4
# 4.7
# 5
# 4.4
# 4.1
# 4.7
# ...

# %%
import csv
with open ("C:/Users/User/Desktop/book1.csv","r")as file:
    csvfile=csv.reader(file)
    i=0
    for line in  csvfile:
        if line[2]== 'BANGRES18DEL02':
            print(line[0], line[2])
    print(line[4])
# Out:
# 2 BANGRES18DEL02
# 947 BANGRES18DEL02
# 2433 BANGRES18DEL02
# 4.9

# %%
import csv
l1=[]
aze=[]
i=0
with open ("C:/Users/User/Desktop/book1.csv","r")as file:
    csvfile=csv.reader(file)
    for j in csvfile:
        i=i+1
        if(i==1):
            continue
        l1.append(j[3])
        aze.append(j[2])
    # print(l1)
    l1.sort()
    aze.sort()
    # print(l1)
    print("maximum delivery persion age in amazon:","deliver persion id=",aze[-1],"aze=",l1[-1])
# Out:
# maximum delivery persion age in amazon: deliver persion id= VADRES20DEL03 aze= 50
